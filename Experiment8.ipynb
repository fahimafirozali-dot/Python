# %%
#program to accept 5 students name and roll number,and map these into dictionary.Sort the dictionary in asc and desc order of their roll no
roll_no=input("Enter 5 roll no:").split()
name=input("Enter 5 name:").split()
students=dict(zip(roll_no,name))
ascending=dict(sorted(students.items()))
descending=dict(sorted(students.items(),reverse=True))
print("dictionary",students)
print("ascending order:",ascending)
print("descending order:",descending)
# Out:
# Enter 5 roll no: 1 2 3 4 5
# Enter 5 name: Anu Rahul George John Peter
# dictionary {'1': 'Anu', '2': 'Rahul', '3': 'George', '4': 'John', '5': 'Peter'}
# ascending order: {'1': 'Anu', '2': 'Rahul', '3': 'George', '4': 'John', '5': 'Peter'}
# descending order: {'5': 'Peter', '4': 'John', '3': 'George', '2': 'Rahul', '1': 'Anu'}

# %%
#program to accept 2 dictionary.Merge two dictionaries and display it
dic1 = dict(zip(input("Enter 3 roll numbers:").split(),input("Enter 3 student names:").split()))
dic2 = dict(zip(input("Enter 2 roll numbers:").split(),input("Enter 2 student names:").split()))
print("dictionary1=",dic1)
print("dictionary2=",dic2)
dic1.update(dic2)
print("Merged dictionary:", dic1)
# Out:
# Enter 3 roll numbers: 1 2 3
# Enter 3 student names: Anu Peter Sara
# Enter 2 roll numbers: 4 5
# Enter 2 student names: George JOhn
# dictionary1= {'1': 'Anu', '2': 'Peter', '3': 'Sara'}
# dictionary2= {'4': 'George', '5': 'JOhn'}
# Merged dictionary: {'1': 'Anu', '2': 'Peter', '3': 'Sara', '4': 'George', '5': 'JOhn'}
