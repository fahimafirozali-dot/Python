# %%
print("PYTHON PROGRAMMING")
# Out:
# PYTHON PROGRAMMING

# %%
print("""Alungalthodi House,Ozhukur PO,
Morayur,Malappuram""")
# Out:
# Alungalthodi House,Ozhukur PO,
# Morayur,Malappuram

# %%
print(int(5/2))
# Out:
# 2

# %%
print(2**3)
# Out:
# 8

# %%
print('"KSB\'s" STUDENTS')
# Out:
# "KSB's" STUDENTS
